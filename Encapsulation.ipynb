# %% [markdown]
# **Encapsulation**
# Is a fundamental principle in OOP that focuses on bundling  data and the methods that operate on that data into a single unit called a class. It allows you to control the access and visibility of the data and methods, providing a way to protect and organize your code. In Python, encapsulation is achieved through the use of access modifiers and property decorators.

# %%
class Person:
  #contructor
  def __init__(self, name, age):
    self.__name = name # Private attribute (Encapsulation)
    self.__age = age

  def display_info(self): #Accessor method (public method)
    print(f"Name: {self.__name}, Age: {self.__age}")

Person=Person("John", 30) #object

Person.display_info()
# Out:
# Name: John, Age: 30

# %%
class Person:
  def __init__(self, name, age):
    self.__name = name # Private attribute (Encapsulation)
    self.__age = age

# %%
class BankAccount:
    def __init__(self, balance):
        self.__balance = balance  # Private attribute (Encapsulation)

    def get_balance(self):  # Accessor method
        return self.__balance

account = BankAccount(1000)
account.get_balance()

# %%
class Person:
  def __init__(self, name, age):
    self.__name = name # Private attribute (Encapsulation)
    self.__age = age   # Private attribute (Encapsulation)

  def display_info(self):
    print(f"Name: {self.__name}, Age: {self.__age}")

# Create an instance of Person
person1 = Person("John", 30)
person1.display_info()

class Student(Person):
  def __init__(self, name, age, student_id):
    super().__init__(name, age)

# Create an instance of Student
student1 = Student("Alice", 20, "12345")  # Pass student_id
student1.display_info()

# %%
class Car:
    def __init__(self, speed=0):
        self.__speed = speed

    def accelerate(self, amount):
        if amount > 0:
            self.__speed += amount

    def brake(self, amount):
        if 0 < amount <= self.__speed:
            self.__speed -= amount

    def get_speed(self):
        return self.__speed

car = Car()
car.accelerate(30)
print(car.get_speed())  # Output: 30
# Out:
# 30

# %%
class Laptop:
    def __init__(self, price):
        self.__price = price

    def set_price(self, new_price):
        if new_price > 0:
            self.__price = new_price

    def get_price(self):
        return self.__price

# %%
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0: self.__balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self.__balance: self.__balance -= amount

    def get_balance(self):
        return self.__balance

# %%
# Question 1: Laptop class
class Laptop:
    def __init__(self, price):
        self.__price = price

    def set_price(self, new_price):
        if new_price > 0:
            self.__price = new_price

    def get_price(self):
        return self.__price

# Question 2: BankAccount class
class BankAccount:
    def __init__(self, balance=0):
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0: self.__balance += amount

    def withdraw(self, amount):
        if 0 < amount <= self.__balance: self.__balance -= amount

    def get_balance(self):
        return self.__balance

# Question 3: Movie class
class Movie:
    def __init__(self, rating):
        self.__rating = max(1, min(10, rating))

    def set_rating(self, new_rating):
        if 1 <= new_rating <= 10:
            self.__rating = new_rating

    def get_rating(self):
        return self.__rating

# Question 4: Book class
class Book:
    def __init__(self, title, author):
        self.__title = title
        self.__author = author

    def get_title(self):
        return self.__title

    def get_author(self):
        return self.__author

# Question 5: Car class
class Car:
    def __init__(self, speed=0):
        self.__speed = speed

    def increase_speed(self, amount):
        if amount > 0: self.__speed += amount

    def decrease_speed(self, amount):
        if 0 < amount <= self.__speed: self.__speed -= amount

    def get_speed(self):
        return self.__speed

# %%
class Movie:
    def __init__(self, rating):
        self.__rating = max(1, min(10, rating))

    def set_rating(self, new_rating):
        if 1 <= new_rating <= 10:
            self.__rating = new_rating

    def get_rating(self):
        return self.__rating
